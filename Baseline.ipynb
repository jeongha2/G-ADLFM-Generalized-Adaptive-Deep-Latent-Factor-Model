# %%
import tensorflow as tf
import random
import os
import pickle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    tf.random.set_seed(seed)

seed_everything(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open("beauty_4/train_id_data.pickle","rb") as fr:
    train_data = pickle.load(fr)

with open("beauty_4/valid_id_data.pickle","rb") as fr:
    valid_data = pickle.load(fr)
    
with open("beauty_4/test_id_data.pickle","rb") as fr:
    test_data = pickle.load(fr)

# %%
with open("beauty_4/train_target.pickle","rb") as fr:
    train_target = pickle.load(fr)
    
with open("beauty_4/valid_target.pickle","rb") as fr:
    valid_target = pickle.load(fr)
    
with open("beauty_4/test_target.pickle","rb") as fr:
    test_target = pickle.load(fr)

# %%
# ID
train_data[0] = tf.convert_to_tensor(train_data[0], dtype=tf.float32)
train_data[1] = tf.convert_to_tensor(train_data[1], dtype=tf.float32)

# %% [markdown]
# ## Model

# %%
from tensorflow import keras
from keras.layers import Input, Embedding, LSTM, Dense, Lambda, Multiply, Bidirectional, Flatten, BatchNormalization, Add
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPool1D
from keras.models import Model
from keras.layers.wrappers import TimeDistributed
import numpy as np
import keras.backend as K
from random import randint

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
description_num = 4

# %%
# set parameters:
V = 249274 
embedding_dim = 50
max_len = 1 
filters_num = 64
kernel_size = 3

# %%
input_1 = Input(shape=(description_num, max_len))
input_2 = Input(shape=(max_len,))
embedding = Embedding(input_dim=V,
                      output_dim=embedding_dim,
                      input_length=max_len)
conv1d = Conv1D(filters=filters_num,
                kernel_size=kernel_size,
                activation='relu',
                padding='same')
maxpool1d = MaxPool1D(max_len)
dense = Dense(15)

input_vector = TimeDistributed(embedding)(input_1)
validation_vector = embedding(input_2)

convolutional_vector = TimeDistributed(conv1d)(input_vector)
validation_conv = conv1d(validation_vector)

maxpooling_vector = TimeDistributed(maxpool1d)(convolutional_vector)
validation_maxpooling = maxpool1d(validation_conv)

middle_output = TimeDistributed(dense)(maxpooling_vector)
middle_validation = dense(validation_maxpooling)

# %%
def change_dim_1(X):
    return K.squeeze(X, 1)

def change_dim_2(X):
    return K.squeeze(X, 2)

def repeat(X):
    return K.repeat_elements(X, description_num, 1)

def repeat1(X):
    return K.repeat_elements(X, 15, 2)

def repeat2(X):
    return K.repeat_elements(X, description_num, 1)

def dot(X, Y):
    return K.dot(X, Y)

def sum_item(X):
    return K.sum(X, axis=2)

def sqrt_item(X):
    return K.sqrt(X)

def cal_denominator(X):
    return 1/(X)

def expand_item(X):
    return K.expand_dims(X, 2)

def expand_rate(X):
    return K.expand_dims(X, 1)

def sum_user(X):
    return K.sum(X, 1)

def sum_rate(X):
    return K.sum(X, 1)

def single_exp(X):
    return K.exp(X)

def sum_exp_denominator(X):
    return 1/(K.sum(K.exp(X), 1))

# %%
middle_output_final = Lambda(change_dim_2)(middle_output)#?*10*15
middle_validation_final = Lambda(repeat)(middle_validation)#?*10*15
molecule = Multiply()([middle_output_final, middle_validation_final])
molecule = Lambda(sum_item)(molecule)

denominator1 = Multiply()([middle_output_final, middle_output_final])
denominator1 = Lambda(sum_item)(denominator1)
denominator1 = Lambda(sqrt_item)(denominator1)

denominator2 = Multiply()([middle_validation_final, middle_validation_final])
denominator2 = Lambda(sum_item)(denominator2)
denominator2 = Lambda(sqrt_item)(denominator2)


denominator = Multiply()([denominator1, denominator2])
denominator = Lambda(cal_denominator)(denominator)

similarity = Multiply()([molecule, denominator])
similarity = Lambda(expand_item)(similarity)
similarity = Lambda(repeat1)(similarity)


user = Multiply()([similarity, middle_output_final])
user = Lambda(sum_user)(user)


item = Lambda(change_dim_1)(middle_validation)


rate_hat = Multiply()([user, item])
rate_hat = Lambda(sum_rate)(rate_hat)
rate_hat = Lambda(expand_rate)(rate_hat)

# %%
model = Model(inputs=[input_1, input_2], outputs=rate_hat)
model.compile(optimizer='adam', loss='mae', metrics=['mse', 'mae', 'mape'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 4, 1)]       0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  time_distributed (TimeDistribu  (None, 4, 1, 50)    12463700    ['input_1[0][0]']
#  ted)
#
#  embedding (Embedding)          (None, 1, 50)        12463700    ['input_2[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 4, 1, 64)    9664        ['time_distributed[0][0]']
#  buted)
#
#  conv1d (Conv1D)                (None, 1, 64)        9664        ['embedding[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, 4, 1, 64)    0           ['time_distributed_1[0][0]']
#  buted)
#
#  max_pooling1d (MaxPooling1D)   (None, 1, 64)        0           ['conv1d[0][0]']
#
#  time_distributed_3 (TimeDistri  (None, 4, 1, 15)    975         ['time_distributed_2[0][0]']
#  buted)
#
#  dense (Dense)                  (None, 1, 15)        975         ['max_pooling1d[0][0]']
#
#  lambda (Lambda)                (None, 4, 15)        0           ['time_distributed_3[0][0]']
#
#  lambda_1 (Lambda)              (None, 4, 15)        0           ['dense[0][0]']
#
#  multiply_1 (Multiply)          (None, 4, 15)        0           ['lambda[0][0]',
#                                                                   'lambda[0][0]']
#
#  multiply_2 (Multiply)          (None, 4, 15)        0           ['lambda_1[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 4)            0           ['multiply_1[0][0]']
#
#  lambda_5 (Lambda)              (None, 4)            0           ['multiply_2[0][0]']
#
#  lambda_4 (Lambda)              (None, 4)            0           ['lambda_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 4)            0           ['lambda_5[0][0]']
#
#  multiply (Multiply)            (None, 4, 15)        0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  multiply_3 (Multiply)          (None, 4)            0           ['lambda_4[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  lambda_2 (Lambda)              (None, 4)            0           ['multiply[0][0]']
#
#  lambda_7 (Lambda)              (None, 4)            0           ['multiply_3[0][0]']
#
#  multiply_4 (Multiply)          (None, 4)            0           ['lambda_2[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  lambda_8 (Lambda)              (None, 4, 1)         0           ['multiply_4[0][0]']
#
#  lambda_9 (Lambda)              (None, 4, 15)        0           ['lambda_8[0][0]']
#
#  multiply_5 (Multiply)          (None, 4, 15)        0           ['lambda_9[0][0]',
#                                                                   'lambda[0][0]']
#
#  lambda_10 (Lambda)             (None, 15)           0           ['multiply_5[0][0]']
#
#  lambda_11 (Lambda)             (None, 15)           0           ['dense[0][0]']
#
#  multiply_6 (Multiply)          (None, 15)           0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  lambda_12 (Lambda)             (None,)              0           ['multiply_6[0][0]']
#
#  lambda_13 (Lambda)             (None, 1)            0           ['lambda_12[0][0]']
#
# ==================================================================================================
# Total params: 12,474,339
# Trainable params: 12,474,339
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
hist = model.fit(train_data, train_target,
                 validation_data=(valid_data, valid_target),
                 steps_per_epoch=256,
                 validation_steps=256,
                 epochs=30,
                 verbose=1)
# Out:
# Epoch 1/30
# 256/256 [==============================] - 15s 13ms/step - loss: 1.2728 - mse: 3.9141 - mae: 1.2728 - mape: 51.5048 - val_loss: 0.8209 - val_mse: 2.0159 - val_mae: 0.8209 - val_mape: 46.3179
# Epoch 2/30
# 256/256 [==============================] - 4s 15ms/step - loss: 0.7835 - mse: 1.8645 - mae: 0.7835 - mape: 43.6805 - val_loss: 0.8307 - val_mse: 1.9007 - val_mae: 0.8307 - val_mape: 45.1585
# Epoch 3/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.7100 - mse: 1.5096 - mae: 0.7100 - mape: 38.2580 - val_loss: 0.8605 - val_mse: 1.8463 - val_mae: 0.8605 - val_mape: 44.4644
# Epoch 4/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.6630 - mse: 1.3557 - mae: 0.6630 - mape: 35.2478 - val_loss: 0.8665 - val_mse: 1.8669 - val_mae: 0.8665 - val_mape: 44.4160
# Epoch 5/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.6352 - mse: 1.2619 - mae: 0.6352 - mape: 33.3277 - val_loss: 0.8880 - val_mse: 1.8289 - val_mae: 0.8880 - val_mape: 44.0290
# Epoch 6/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.6125 - mse: 1.1566 - mae: 0.6125 - mape: 31.5711 - val_loss: 0.9041 - val_mse: 1.8345 - val_mae: 0.9041 - val_mape: 43.9253
# Epoch 7/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.5839 - mse: 1.0293 - mae: 0.5839 - mape: 29.5409 - val_loss: 0.9151 - val_mse: 1.8418 - val_mae: 0.9151 - val_mape: 43.9442
# Epoch 8/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5480 - mse: 0.8993 - mae: 0.5480 - mape: 27.3684 - val_loss: 0.9371 - val_mse: 1.8379 - val_mae: 0.9371 - val_mape: 43.7962
# Epoch 9/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5112 - mse: 0.7817 - mae: 0.5112 - mape: 25.2427 - val_loss: 0.9523 - val_mse: 1.8454 - val_mae: 0.9523 - val_mape: 43.7679
# Epoch 10/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.4768 - mse: 0.6811 - mae: 0.4768 - mape: 23.2826 - val_loss: 0.9606 - val_mse: 1.9015 - val_mae: 0.9606 - val_mape: 44.2033
# Epoch 11/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.4472 - mse: 0.6056 - mae: 0.4472 - mape: 21.6982 - val_loss: 0.9647 - val_mse: 1.8662 - val_mae: 0.9647 - val_mape: 43.9219
# Epoch 12/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.4212 - mse: 0.5437 - mae: 0.4212 - mape: 20.3477 - val_loss: 0.9767 - val_mse: 1.8278 - val_mae: 0.9767 - val_mape: 43.5599
# Epoch 13/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.3986 - mse: 0.4941 - mae: 0.3986 - mape: 19.1891 - val_loss: 0.9880 - val_mse: 1.8468 - val_mae: 0.9880 - val_mape: 43.5815
# Epoch 14/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.3797 - mse: 0.4542 - mae: 0.3797 - mape: 18.2540 - val_loss: 1.0013 - val_mse: 1.8767 - val_mae: 1.0013 - val_mape: 43.6695
# Epoch 15/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.3652 - mse: 0.4217 - mae: 0.3652 - mape: 17.4773 - val_loss: 0.9937 - val_mse: 1.8710 - val_mae: 0.9937 - val_mape: 43.7722
# Epoch 16/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.3512 - mse: 0.3956 - mae: 0.3512 - mape: 16.8078 - val_loss: 1.0025 - val_mse: 1.8866 - val_mae: 1.0025 - val_mape: 43.8646
# Epoch 17/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.3376 - mse: 0.3718 - mae: 0.3376 - mape: 16.1975 - val_loss: 1.0115 - val_mse: 1.8804 - val_mae: 1.0115 - val_mape: 43.6717
# Epoch 18/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.3274 - mse: 0.3523 - mae: 0.3274 - mape: 15.6915 - val_loss: 1.0202 - val_mse: 1.9008 - val_mae: 1.0202 - val_mape: 43.6643
# Epoch 19/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.3169 - mse: 0.3350 - mae: 0.3169 - mape: 15.2229 - val_loss: 1.0167 - val_mse: 1.9020 - val_mae: 1.0167 - val_mape: 43.8396
# Epoch 20/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.3082 - mse: 0.3208 - mae: 0.3082 - mape: 14.8286 - val_loss: 1.0138 - val_mse: 1.9131 - val_mae: 1.0138 - val_mape: 43.9727
# Epoch 21/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.3007 - mse: 0.3087 - mae: 0.3007 - mape: 14.4870 - val_loss: 1.0208 - val_mse: 1.9056 - val_mae: 1.0208 - val_mape: 43.8217
# Epoch 22/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2937 - mse: 0.2977 - mae: 0.2937 - mape: 14.1582 - val_loss: 1.0239 - val_mse: 1.9238 - val_mae: 1.0239 - val_mape: 43.9383
# Epoch 23/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.2891 - mse: 0.2879 - mae: 0.2891 - mape: 13.9088 - val_loss: 1.0260 - val_mse: 1.9163 - val_mae: 1.0260 - val_mape: 43.8241
# Epoch 24/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2833 - mse: 0.2791 - mae: 0.2833 - mape: 13.6455 - val_loss: 1.0264 - val_mse: 1.9223 - val_mae: 1.0264 - val_mape: 43.9382
# Epoch 25/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2781 - mse: 0.2714 - mae: 0.2781 - mape: 13.4122 - val_loss: 1.0273 - val_mse: 1.9292 - val_mae: 1.0273 - val_mape: 43.9637
# Epoch 26/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2730 - mse: 0.2639 - mae: 0.2730 - mape: 13.1965 - val_loss: 1.0380 - val_mse: 1.9281 - val_mae: 1.0380 - val_mape: 43.7485
# Epoch 27/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2685 - mse: 0.2575 - mae: 0.2685 - mape: 12.9951 - val_loss: 1.0380 - val_mse: 1.9061 - val_mae: 1.0380 - val_mape: 43.6389
# Epoch 28/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2650 - mse: 0.2517 - mae: 0.2650 - mape: 12.8335 - val_loss: 1.0305 - val_mse: 1.9516 - val_mae: 1.0305 - val_mape: 44.1768
# Epoch 29/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2614 - mse: 0.2462 - mae: 0.2614 - mape: 12.6568 - val_loss: 1.0410 - val_mse: 1.9350 - val_mae: 1.0410 - val_mape: 43.8811
# Epoch 30/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2584 - mse: 0.2417 - mae: 0.2584 - mape: 12.5180 - val_loss: 1.0398 - val_mse: 1.9373 - val_mae: 1.0398 - val_mape: 43.8315

# %%
scores = model.evaluate(test_data, test_target, steps=2500)
print(scores)
# Out:
# 2452/2500 [============================>.] - ETA: 0s - loss: 1.0511 - mse: 1.9739 - mae: 1.0511 - mape: 44.3173WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2500 batches). You may need to use the repeat() function when building your dataset.
# 2500/2500 [==============================] - 8s 3ms/step - loss: 1.0514 - mse: 1.9752 - mae: 1.0514 - mape: 44.3359
# [1.051406741142273, 1.9751557111740112, 1.051406741142273, 44.33586120605469]
