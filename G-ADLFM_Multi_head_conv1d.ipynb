# %%
import tensorflow as tf
import random
import os
import pickle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    tf.random.set_seed(seed)

seed_everything(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open("beauty_4/train_id_data.pickle","rb") as fr:
    train_data = pickle.load(fr)

with open("beauty_4/valid_id_data.pickle","rb") as fr:
    valid_data = pickle.load(fr)
    
with open("beauty_4/test_id_data.pickle","rb") as fr:
    test_data = pickle.load(fr)

# %%
with open("beauty_4/train_target.pickle","rb") as fr:
    train_target = pickle.load(fr)
    
with open("beauty_4/valid_target.pickle","rb") as fr:
    valid_target = pickle.load(fr)
    
with open("beauty_4/test_target.pickle","rb") as fr:
    test_target = pickle.load(fr)

# %%
# # ID
train_data[0] = tf.convert_to_tensor(train_data[0], dtype=tf.float32)
train_data[1] = tf.convert_to_tensor(train_data[1], dtype=tf.float32)

# %% [markdown]
# ## Model

# %%
# !pip install keras_multi_head
#!pip install keras_self_attention
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_multi_head
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
# Collecting keras-self-attention==0.51.0
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-self-attention==0.51.0->keras_multi_head) (1.21.6)
# Building wheels for collected packages: keras-multi-head, keras-self-attention
#   Building wheel for keras-multi-head (setup.py) ... done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=14993 sha256=bdbca023da97c3fc4405fdaf277ee2649b8ed10f388c316a7551000eabdc4466
#   Stored in directory: /root/.cache/pip/wheels/86/aa/3c/9d15d24005179dae08ff291ce99c754b296347817d076fd9fb
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18912 sha256=58a28523841a956def85b77653a69cb4270cafec1ba3231a73ed5afdc30b36ee
#   Stored in directory: /root/.cache/pip/wheels/95/b1/a8/5ee00cc137940b2f6fa198212e8f45d813d0e0d9c3a04035a3
# Successfully built keras-multi-head keras-self-attention
# Installing collected packages: keras-self-attention, keras-multi-head
# Successfully installed keras-multi-head-0.29.0 keras-self-attention-0.51.0

# %%
from tensorflow import keras
from keras.layers import Input, Embedding, LSTM, Dense, Lambda, Multiply, Bidirectional, Flatten, BatchNormalization, Add
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPool1D
from keras.models import Model
from keras.layers.wrappers import TimeDistributed
import numpy as np
import keras.backend as K
from random import randint
from keras_multi_head import MultiHead
#from keras_self_attention import SeqSelfAttention as Attention

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
description_num = 4

# %%
# set parameters:
V = 249274 
embedding_dim = 50
max_len = 1 
filters_num = 64
kernel_size = 3

# %%
input_1 = Input(shape=(description_num, max_len))
input_2 = Input(shape=(max_len,))
embedding = Embedding(input_dim=V,
                      output_dim=embedding_dim,
                      input_length=max_len)
conv1d = Conv1D(filters=filters_num,
                kernel_size=kernel_size,
                activation='relu',
                padding='same')
maxpool1d = MaxPool1D(max_len)
batchnorm1d = BatchNormalization()
dense = Dense(15)

input_vector = TimeDistributed(embedding)(input_1)
validation_vector = embedding(input_2)

convolutional_vector = TimeDistributed(MultiHead(conv1d))(input_vector)
validation_conv = MultiHead(conv1d)(validation_vector)
convolutional_vector = tf.keras.backend.squeeze(convolutional_vector, axis=4)
validation_conv = tf.keras.backend.squeeze(validation_conv, axis=3)

maxpooling_vector = TimeDistributed(maxpool1d)(convolutional_vector)
validation_maxpooling = maxpool1d(validation_conv)

middle_output = TimeDistributed(dense)(maxpooling_vector)
middle_validation = dense(validation_maxpooling)

# %%
def change_dim_1(X):
    return K.squeeze(X, 1)

def change_dim_2(X):
    return K.squeeze(X, 2)

def repeat(X):
    return K.repeat_elements(X, description_num, 1)

def repeat1(X):
    return K.repeat_elements(X, 15, 2)

def repeat2(X):
    return K.repeat_elements(X, description_num, 1)

def dot(X, Y):
    return K.dot(X, Y)

def sum_item(X):
    return K.sum(X, axis=2)

def sqrt_item(X):
    return K.sqrt(X)

def cal_denominator(X):
    return 1/(X)

def expand_item(X):
    return K.expand_dims(X, 2)

def expand_rate(X):
    return K.expand_dims(X, 1)

def sum_user(X):
    return K.sum(X, 1)

def sum_rate(X):
    return K.sum(X, 1)

def single_exp(X):
    return K.exp(X)

def sum_exp_denominator(X):
    return 1/(K.sum(K.exp(X), 1))

# %%
middle_output_final = Lambda(change_dim_2)(middle_output)#?*10*15
middle_validation_final = Lambda(repeat)(middle_validation)#?*10*15
molecule = Multiply()([middle_output_final, middle_validation_final])
molecule = Lambda(sum_item)(molecule)

denominator1 = Multiply()([middle_output_final, middle_output_final])
denominator1 = Lambda(sum_item)(denominator1)
denominator1 = Lambda(sqrt_item)(denominator1)

denominator2 = Multiply()([middle_validation_final, middle_validation_final])
denominator2 = Lambda(sum_item)(denominator2)
denominator2 = Lambda(sqrt_item)(denominator2)


denominator = Multiply()([denominator1, denominator2])
denominator = Lambda(cal_denominator)(denominator)

similarity = Multiply()([molecule, denominator])
similarity = Lambda(expand_item)(similarity)
similarity = Lambda(repeat1)(similarity)


user = Multiply()([similarity, middle_output_final])
user = Lambda(sum_user)(user)


item = Lambda(change_dim_1)(middle_validation)


rate_hat = Multiply()([user, item])
rate_hat = Lambda(sum_rate)(rate_hat)
rate_hat = Lambda(expand_rate)(rate_hat)

# %%
model = Model(inputs=[input_1, input_2], outputs=rate_hat)
model.compile(optimizer='adam', loss='mae', metrics=['mse', 'mae', 'mape'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 4, 1)]       0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  time_distributed (TimeDistribu  (None, 4, 1, 50)    12463700    ['input_1[0][0]']
#  ted)
#
#  embedding (Embedding)          (None, 1, 50)        12463700    ['input_2[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 4, 1, 64, 1)  9664       ['time_distributed[0][0]']
#  buted)
#
#  multi_head_1 (MultiHead)       (None, 1, 64, 1)     9664        ['embedding[0][0]']
#
#  tf.compat.v1.squeeze (TFOpLamb  (None, 4, 1, 64)    0           ['time_distributed_1[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_1 (TFOpLa  (None, 1, 64)       0           ['multi_head_1[0][0]']
#  mbda)
#
#  time_distributed_2 (TimeDistri  (None, 4, 1, 64)    0           ['tf.compat.v1.squeeze[0][0]']
#  buted)
#
#  max_pooling1d (MaxPooling1D)   (None, 1, 64)        0           ['tf.compat.v1.squeeze_1[0][0]']
#
#  time_distributed_3 (TimeDistri  (None, 4, 1, 15)    975         ['time_distributed_2[0][0]']
#  buted)
#
#  dense (Dense)                  (None, 1, 15)        975         ['max_pooling1d[0][0]']
#
#  lambda (Lambda)                (None, 4, 15)        0           ['time_distributed_3[0][0]']
#
#  lambda_1 (Lambda)              (None, 4, 15)        0           ['dense[0][0]']
#
#  multiply_1 (Multiply)          (None, 4, 15)        0           ['lambda[0][0]',
#                                                                   'lambda[0][0]']
#
#  multiply_2 (Multiply)          (None, 4, 15)        0           ['lambda_1[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 4)            0           ['multiply_1[0][0]']
#
#  lambda_5 (Lambda)              (None, 4)            0           ['multiply_2[0][0]']
#
#  lambda_4 (Lambda)              (None, 4)            0           ['lambda_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 4)            0           ['lambda_5[0][0]']
#
#  multiply (Multiply)            (None, 4, 15)        0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  multiply_3 (Multiply)          (None, 4)            0           ['lambda_4[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  lambda_2 (Lambda)              (None, 4)            0           ['multiply[0][0]']
#
#  lambda_7 (Lambda)              (None, 4)            0           ['multiply_3[0][0]']
#
#  multiply_4 (Multiply)          (None, 4)            0           ['lambda_2[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  lambda_8 (Lambda)              (None, 4, 1)         0           ['multiply_4[0][0]']
#
#  lambda_9 (Lambda)              (None, 4, 15)        0           ['lambda_8[0][0]']
#
#  multiply_5 (Multiply)          (None, 4, 15)        0           ['lambda_9[0][0]',
#                                                                   'lambda[0][0]']
#
#  lambda_10 (Lambda)             (None, 15)           0           ['multiply_5[0][0]']
#
#  lambda_11 (Lambda)             (None, 15)           0           ['dense[0][0]']
#
#  multiply_6 (Multiply)          (None, 15)           0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  lambda_12 (Lambda)             (None,)              0           ['multiply_6[0][0]']
#
#  lambda_13 (Lambda)             (None, 1)            0           ['lambda_12[0][0]']
#
# ==================================================================================================
# Total params: 12,484,003
# Trainable params: 12,484,003
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
hist = model.fit(train_data, train_target,
                 validation_data=(valid_data, valid_target),
                 steps_per_epoch=256,
                 validation_steps=256,
                 epochs=30)
# Out:
# Epoch 1/30
# 256/256 [==============================] - 15s 11ms/step - loss: 1.2925 - mse: 4.0665 - mae: 1.2925 - mape: 51.9321 - val_loss: 0.8062 - val_mse: 2.1113 - val_mae: 0.8062 - val_mape: 46.6406
# Epoch 2/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.7770 - mse: 1.8145 - mae: 0.7770 - mape: 43.0946 - val_loss: 0.8340 - val_mse: 1.8867 - val_mae: 0.8340 - val_mape: 45.0301
# Epoch 3/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.6869 - mse: 1.4259 - mae: 0.6869 - mape: 36.8144 - val_loss: 0.8620 - val_mse: 1.9017 - val_mae: 0.8620 - val_mape: 44.5517
# Epoch 4/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5996 - mse: 1.1782 - mae: 0.5996 - mape: 31.8516 - val_loss: 0.8773 - val_mse: 1.9102 - val_mae: 0.8773 - val_mape: 44.1601
# Epoch 5/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5476 - mse: 1.0329 - mae: 0.5476 - mape: 28.4962 - val_loss: 0.8940 - val_mse: 1.9444 - val_mae: 0.8940 - val_mape: 44.0821
# Epoch 6/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.5087 - mse: 0.9258 - mae: 0.5087 - mape: 26.0102 - val_loss: 0.8955 - val_mse: 1.9408 - val_mae: 0.8955 - val_mape: 44.0672
# Epoch 7/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.4794 - mse: 0.8400 - mae: 0.4794 - mape: 24.2648 - val_loss: 0.9110 - val_mse: 1.9233 - val_mae: 0.9110 - val_mape: 43.8129
# Epoch 8/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.4511 - mse: 0.7654 - mae: 0.4511 - mape: 22.7354 - val_loss: 0.9256 - val_mse: 1.9598 - val_mae: 0.9256 - val_mape: 43.9092
# Epoch 9/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.4270 - mse: 0.6974 - mae: 0.4270 - mape: 21.3753 - val_loss: 0.9275 - val_mse: 1.9044 - val_mae: 0.9275 - val_mape: 43.5471
# Epoch 10/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.4039 - mse: 0.6340 - mae: 0.4039 - mape: 20.1135 - val_loss: 0.9368 - val_mse: 1.9243 - val_mae: 0.9368 - val_mape: 43.5721
# Epoch 11/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.3830 - mse: 0.5751 - mae: 0.3830 - mape: 18.9378 - val_loss: 0.9426 - val_mse: 1.8946 - val_mae: 0.9426 - val_mape: 43.3740
# Epoch 12/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.3634 - mse: 0.5191 - mae: 0.3634 - mape: 17.8255 - val_loss: 0.9495 - val_mse: 1.9181 - val_mae: 0.9495 - val_mape: 43.4929
# Epoch 13/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.3464 - mse: 0.4687 - mae: 0.3464 - mape: 16.7964 - val_loss: 0.9568 - val_mse: 1.9126 - val_mae: 0.9568 - val_mape: 43.3873
# Epoch 14/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.3290 - mse: 0.4244 - mae: 0.3290 - mape: 15.8336 - val_loss: 0.9584 - val_mse: 1.9210 - val_mae: 0.9584 - val_mape: 43.6143
# Epoch 15/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.3134 - mse: 0.3864 - mae: 0.3134 - mape: 14.9949 - val_loss: 0.9698 - val_mse: 1.8870 - val_mae: 0.9698 - val_mape: 43.2104
# Epoch 16/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2992 - mse: 0.3531 - mae: 0.2992 - mape: 14.2034 - val_loss: 0.9782 - val_mse: 1.8942 - val_mae: 0.9782 - val_mape: 43.1258
# Epoch 17/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2868 - mse: 0.3236 - mae: 0.2868 - mape: 13.4941 - val_loss: 0.9803 - val_mse: 1.8980 - val_mae: 0.9803 - val_mape: 43.1517
# Epoch 18/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2746 - mse: 0.2987 - mae: 0.2746 - mape: 12.8493 - val_loss: 0.9775 - val_mse: 1.9119 - val_mae: 0.9775 - val_mape: 43.3257
# Epoch 19/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.2622 - mse: 0.2760 - mae: 0.2622 - mape: 12.2466 - val_loss: 0.9838 - val_mse: 1.9343 - val_mae: 0.9838 - val_mape: 43.4208
# Epoch 20/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2522 - mse: 0.2562 - mae: 0.2522 - mape: 11.6938 - val_loss: 0.9894 - val_mse: 1.9339 - val_mae: 0.9894 - val_mape: 43.3547
# Epoch 21/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2442 - mse: 0.2395 - mae: 0.2442 - mape: 11.2465 - val_loss: 0.9910 - val_mse: 1.9353 - val_mae: 0.9910 - val_mape: 43.3614
# Epoch 22/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2358 - mse: 0.2243 - mae: 0.2358 - mape: 10.7906 - val_loss: 0.9883 - val_mse: 1.9284 - val_mae: 0.9883 - val_mape: 43.4292
# Epoch 23/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2281 - mse: 0.2110 - mae: 0.2281 - mape: 10.3916 - val_loss: 0.9941 - val_mse: 1.9200 - val_mae: 0.9941 - val_mape: 43.2619
# Epoch 24/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2217 - mse: 0.1989 - mae: 0.2217 - mape: 10.0289 - val_loss: 0.9941 - val_mse: 1.9268 - val_mae: 0.9941 - val_mape: 43.3574
# Epoch 25/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2149 - mse: 0.1881 - mae: 0.2149 - mape: 9.6795 - val_loss: 1.0059 - val_mse: 1.9062 - val_mae: 1.0059 - val_mape: 43.1009
# Epoch 26/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2096 - mse: 0.1783 - mae: 0.2096 - mape: 9.3657 - val_loss: 1.0005 - val_mse: 1.9238 - val_mae: 1.0005 - val_mape: 43.2308
# Epoch 27/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.2042 - mse: 0.1696 - mae: 0.2042 - mape: 9.0871 - val_loss: 0.9985 - val_mse: 1.9557 - val_mae: 0.9985 - val_mape: 43.5762
# Epoch 28/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.1988 - mse: 0.1611 - mae: 0.1988 - mape: 8.7979 - val_loss: 1.0025 - val_mse: 1.9425 - val_mae: 1.0025 - val_mape: 43.3682
# Epoch 29/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.1944 - mse: 0.1547 - mae: 0.1944 - mape: 8.5630 - val_loss: 1.0047 - val_mse: 1.9293 - val_mae: 1.0047 - val_mape: 43.2871
# Epoch 30/30
# 256/256 [==============================] - 3s 10ms/step - loss: 0.1905 - mse: 0.1479 - mae: 0.1905 - mape: 8.3439 - val_loss: 1.0008 - val_mse: 1.9544 - val_mae: 1.0008 - val_mape: 43.4959

# %%
scores = model.evaluate(test_data, test_target, steps=2500)
# Out:
# 2452/2500 [============================>.] - ETA: 0s - loss: 1.0083 - mse: 1.9874 - mae: 1.0083 - mape: 43.8625WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2500 batches). You may need to use the repeat() function when building your dataset.
# 2500/2500 [==============================] - 7s 3ms/step - loss: 1.0083 - mse: 1.9874 - mae: 1.0083 - mape: 43.8773
